# %%
#importing libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df.to_csv('data_jobs_export.csv', index=False)

# %%
#importing libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

data_scientist_df = df[df['job_title_short'] == 'Data Scientist']
data_scientist_df.to_csv('data_scientist_jobs.csv', index=False)

# %%
#importing libraries
import openpyxl
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

job_posted_NY = df[df['job_location'] == 'New York, NY']
job_posted_NY.to_excel('new_york_jobs.xlsx', index=False)
